# %%
a = 15

# %%
print(a)
# Out:
# 15

# %%
b = 10

# %%
print(a+b)
# Out:
# 25

# %%
import pandas as pd

# %%
hokej = pd.read_csv("/content/drive/MyDrive/Škola/MAWO/cvicenie_1/hokejisti_data_set.csv")

# %%
hokej
# Out:
#                hrac     post                 klub  pocet_golov  pocet_zapasov
# 0  Tesfalem Tewolde  brankar        Dynamo Malabo            0             22
# 1     Theodros Zula  obranca  North Coyotes Bioko            2             20
# 2       Nebay Welde  obranca      Sporting Malabo            1             12
# 3        Abel Fikru  utocnik  Thirsty Camels Luba           10             21
# 4     Rezene Girmay  utocnik   Hot Penguins Bioko            4             16
# 5     Wayne Gretzky  utocnik    Los Angeles Kings           18             21

# %%
hokej.head()
# Out:
#                hrac     post                 klub  pocet_golov  pocet_zapasov
# 0  Tesfalem Tewolde  brankar        Dynamo Malabo            0             22
# 1     Theodros Zula  obranca  North Coyotes Bioko            2             20
# 2       Nebay Welde  obranca      Sporting Malabo            1             12
# 3        Abel Fikru  utocnik  Thirsty Camels Luba           10             21
# 4     Rezene Girmay  utocnik   Hot Penguins Bioko            4             16

# %%
hokej.head(2)
# Out:
#                hrac     post                 klub  pocet_golov  pocet_zapasov
# 0  Tesfalem Tewolde  brankar        Dynamo Malabo            0             22
# 1     Theodros Zula  obranca  North Coyotes Bioko            2             20

# %%
hokej.tail(2)
# Out:
#             hrac     post                klub  pocet_golov  pocet_zapasov
# 4  Rezene Girmay  utocnik  Hot Penguins Bioko            4             16
# 5  Wayne Gretzky  utocnik   Los Angeles Kings           18             21

# %%
hokej
# Out:
#                hrac     post                 klub  pocet_golov  pocet_zapasov
# 0  Tesfalem Tewolde  brankar        Dynamo Malabo            0             22
# 1     Theodros Zula  obranca  North Coyotes Bioko            2             20
# 2       Nebay Welde  obranca      Sporting Malabo            1             12
# 3        Abel Fikru  utocnik  Thirsty Camels Luba           10             21
# 4     Rezene Girmay  utocnik   Hot Penguins Bioko            4             16
# 5     Wayne Gretzky  utocnik    Los Angeles Kings           18             21

# %%
hokej["klub"]
# Out:
# 0          Dynamo Malabo
# 1    North Coyotes Bioko
# 2        Sporting Malabo
# 3    Thirsty Camels Luba
# 4     Hot Penguins Bioko
# 5      Los Angeles Kings
# Name: klub, dtype: object

# %%
hokej["hrac"]
# Out:
# 0    Tesfalem Tewolde
# 1       Theodros Zula
# 2         Nebay Welde
# 3          Abel Fikru
# 4       Rezene Girmay
# 5       Wayne Gretzky
# Name: hrac, dtype: object

# %%
hokej["hrac"][5]
# Out:
# 'Wayne Gretzky'

# %%
hokej["pocet_golov"].sum()
# Out:
# 35

# %%
hokej["priemer_na_zapas"] = hokej["pocet_golov"] / hokej["pocet_zapasov"]

# %%
hokej.head()
# Out:
#                hrac     post  ... pocet_zapasov  priemer_na_zapas
# 0  Tesfalem Tewolde  brankar  ...            22          0.000000
# 1     Theodros Zula  obranca  ...            20          0.100000
# 2       Nebay Welde  obranca  ...            12          0.083333
# 3        Abel Fikru  utocnik  ...            21          0.476190
# 4     Rezene Girmay  utocnik  ...            16          0.250000
#
# [5 rows x 6 columns]

# %%
hokej
# Out:
#                hrac     post  ... pocet_zapasov  priemer_na_zapas
# 0  Tesfalem Tewolde  brankar  ...            22          0.000000
# 1     Theodros Zula  obranca  ...            20          0.100000
# 2       Nebay Welde  obranca  ...            12          0.083333
# 3        Abel Fikru  utocnik  ...            21          0.476190
# 4     Rezene Girmay  utocnik  ...            16          0.250000
# 5     Wayne Gretzky  utocnik  ...            21          0.857143
#
# [6 rows x 6 columns]
